# %% [markdown]
# # Assignment: Unsupervised Machine Learning \ Genetic Algorithms

# %% [markdown]
# In this assignment you will experience with Genetic Algorithms (GAs), starting from a basic implementation, continuing with dedicated improvements, and later applying it in various unsupervised machine learning scenarios.

# %% [markdown]
# ## Part 1: Time Series of 'Likes' Influenced by Personalization

# %% [markdown]
# Various personalization algorithms are applied in e-commerce and other kinds of websites/apps in order to increase purchases or user engagement.
#
# The following time series were collected over a period of 20 months from a large online retail store. In this study, during the first 10 months (normalized as the period from month -10 to month 0) a contextual personalization algorithm was applied in order to increase user engagement (measured as the accumulated number of 'Likes' on products shared via Facebook). As in the case with many contextual approaches, this algorithm suffered from the 'filter bubble' problem (https://en.wikipedia.org/wiki/Filter_bubble), and therefore reached a plateau quite quickly.
#
# Nonetheless, this step enabled a more advanced collaborative filtering algorithm to analyze the collected data, learn, and increase user engagement once it was applied in the following 10 months. A classic inflection point was detected after the transition to the new algorithm. A domain expert envisioned the inflection dynamics will behave similarly to the formula f(x) = ax^3 + bx^2 + cx + d. The values of a, b, c and d were found to be 4.8, 12.1, 53.2 and 6219, respectively.
#
# << Please note: This function is an analytical solution, used here for simplifying the actual study, where a dynamic model was created with ODEs >>
#
# We are given a sample sparse data of users from 10 different European countries. In this project, we will implement a simple GA in order to fit our data to the above-mentioned function, and discover the parameters for a, b, c and d.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read measured data from an Excel file

# %%
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ddd8d37a-7470-4fe0-ac93-f41627b7e39a" name="files[]" multiple disabled />
#      <output id="result-ddd8d37a-7470-4fe0-ac93-f41627b7e39a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving European Measurements.xlsx to European Measurements.xlsx

# %%
xlsx = pd.ExcelFile(io.BytesIO(uploaded['European Measurements.xlsx']))
sheet1 = xlsx.parse(3) # Note the other datasets in the file.
variables = ["Month","Avg. Likes"]
data = sheet1.loc[:, variables].values
print(data)
# Out:
# [[-9.70000000e+00  1.93303385e+03]
#  [-9.10000000e+00  3.07678202e+03]
#  [-7.70000000e+00  4.61959427e+03]
#  [-7.30000000e+00  4.87640388e+03]
#  [-7.20000000e+00  5.27621777e+03]
#  [-6.20000000e+00  5.76967851e+03]
#  [-4.70000000e+00  5.26728526e+03]
#  [-4.10000000e+00  6.40777934e+03]
#  [-3.30000000e+00  6.05631612e+03]
#  [-2.70000000e+00  6.10216500e+03]
#  [-2.50000000e+00  5.18359545e+03]
#  [-2.30000000e+00  7.03041233e+03]
#  [-1.90000000e+00  5.69790109e+03]
#  [-1.80000000e+00  5.42920417e+03]
#  [-1.20000000e+00  5.23662184e+03]
#  [-9.00000000e-01  6.28278124e+03]
#  [-1.00000000e-01  6.53285159e+03]
#  [ 2.00000000e-01  5.78284515e+03]
#  [ 3.00000000e-01  6.57445814e+03]
#  [ 4.00000000e-01  5.25761264e+03]
#  [ 1.10000000e+00  5.86568880e+03]
#  [ 1.50000000e+00  6.92127198e+03]
#  [ 1.60000000e+00  6.15982519e+03]
#  [ 2.10000000e+00  6.87265063e+03]
#  [ 2.20000000e+00  5.57408399e+03]
#  [ 2.50000000e+00  5.88485867e+03]
#  [ 5.20000000e+00  6.75130936e+03]
#  [ 5.40000000e+00  7.32399792e+03]
#  [ 5.90000000e+00  7.52506753e+03]
#  [ 7.70000000e+00  9.18581240e+03]
#  [ 8.20000000e+00  1.04493680e+04]
#  [ 8.60000000e+00  1.15189098e+04]
#  [ 8.80000000e+00  1.11537874e+04]
#  [ 8.90000000e+00  1.11901243e+04]
#  [ 9.50000000e+00  1.13409561e+04]]

# %% [markdown]
# ### Simple GA mechanism

# %%
def fitness_function(data, pop):
    fitness = []
    for solution in range(len(pop)):
        for event in range(len(data)):
            error = 0;
            event_time = data[event][0]
            event_measured = data[event][1]
            event_expected = pop[solution][0]*event_time**3 + pop[solution][1]*event_time**2 + pop[solution][2]*event_time + pop[solution][3]
            error +=(event_expected - event_measured)**2
        fitness.append(1/error) # We use 1/error in order to use a maximization mechanism, while we want to minimize the error
    return fitness

def biased_selection(pop, fitness, num_parents):
    sorted_fitness_args = np.argsort(fitness)
    return pop[sorted_fitness_args[-num_parents:],:]
    # parents = np.empty((num_parents, pop.shape[1]))
    # for parent_num in range(num_parents):
    #     max_fitness_idx = np.where(fitness == np.max(fitness))
    #     max_fitness_idx = max_fitness_idx[0][0]
    #     parents[parent_num, :] = pop[max_fitness_idx, :]
    #     fitness[max_fitness_idx] = -99999999999
    # return parents

def recombination(parents, offspring_size):
    offspring = np.empty(offspring_size)
    recombination_point = np.uint8(offspring_size[1]/2)
    for k in range(offspring_size[0]):
        parent1_idx = k%parents.shape[0]
        parent2_idx = (k+1)%parents.shape[0]
        offspring[k, 0:recombination_point] = parents[parent1_idx, 0:recombination_point]
        offspring[k, recombination_point:] = parents[parent2_idx, recombination_point:]
    return offspring

def mutation(offspring_recombination):
    for idx in range(offspring_recombination.shape[0]):
        random_value = np.random.randint(-100, 100, 1)
        random_index = np.random.randint(0,offspring_recombination.shape[1],1)
        offspring_recombination[idx, random_index] = offspring_recombination[idx, random_index] + random_value
    return offspring_recombination

# %% [markdown]
# ### GA application for fitting time series data

# %%
# GA Parameters
formula_degree = 4
number_of_solutions = 500
number_of_parents = 250
population_size = (number_of_solutions,formula_degree) 
number_of_generations = 20
best_outputs = []

# Genesis
new_population = np.random.randint(low=0, high=10000, size=population_size)
print("The population of the first generation: ")
print(new_population)

# Evolution
print ("\nEvolution:")
for generation in range(number_of_generations):

    fitness = fitness_function(data, new_population)
    print("Generation = ", generation, "\tBest fitness = ", round(1/np.max(fitness),5))
    # best_outputs.append(np.max(np.sum(new_population*formula_degree, axis=1)))
    best_outputs.append(round(1/np.max(fitness),5))
    parents = biased_selection(new_population, fitness, number_of_parents)
    offspring_recombination = recombination(parents, offspring_size=(population_size[0]-parents.shape[0], formula_degree))
    offspring_mutation = mutation(offspring_recombination)
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation

# Results
print("\nThe population of the last generation: ")
print(new_population)
fitness = fitness_function(data, new_population)
best_match_idx = np.where(fitness == np.max(fitness))
print("Best solution: ", new_population[best_match_idx, :])

# Chart
plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Best Fitness Score")
plt.show()
# Out:
# The population of the first generation:
# [[5859 4186 3257 1476]
#  [6061 6857 3469 1972]
#  [6139 5638 1011 6153]
#  ...
#  [5673 7650 2557 7175]
#  [4062 2365 7653 2490]
#  [ 640 7285 1986 8789]]
#
# Evolution:
# Generation =  0 	Best fitness =  3885361606.00274
# Generation =  1 	Best fitness =  2529729749.16609
# Generation =  2 	Best fitness =  2372193472.73747
# Generation =  3 	Best fitness =  10072967.40429
# Generation =  4 	Best fitness =  10072967.40429
# Generation =  5 	Best fitness =  5826400.75182
# Generation =  6 	Best fitness =  5826400.75182
# Generation =  7 	Best fitness =  4613018.42345
# Generation =  8 	Best fitness =  57861.34392
# Generation =  9 	Best fitness =  57861.34392
# Generation =  10 	Best fitness =  4754.95058
# Generation =  11 	Best fitness =  3131.09069
# Generation =  12 	Best fitness =  3131.09069
# Generation =  13 	Best fitness =  3131.09069
# Generation =  14 	Best fitness =  3131.09069
# Generation =  15 	Best fitness =  1928.86541
# Generation =  16 	Best fitness =  1928.86541
# Generation =  17 	Best fitness =  1928.86541
# Generation =  18 	Best fitness =  1928.86541
# Generation =  19 	Best fitness =  170.14203
#
# The population of the last generation:
# [[-135 1080 2330 5939]
#  [ -54  350 2273 6000]
#  [-135 1108 2404 5793]
#  ...
#  [ -47  264 1207 3278]
#  [ -22  304 1199 3393]
#  [ -36  217 2330 5939]]
# Best solution:  [[[-148 1246 2097 5866]]]

# %% [markdown]
# ## Challenge 231
# Implement a new and improved GA, based on the one above, by taking the following actions:
#
# 1. Make the bias_selection function give more chances to solutions with better fitness values, but not necesseraly take the best ones, as currently done.
# 2. Make the recombination function make real random recombination along the chromosome and between chromosomes
# 3. Change the mutation rate and/or scale to better avoid local minima while keeping evolution time short
# 4. Apply a smarter stopping criterion
# 5. Consider different GA parameters in order to reach better results

# %%
#1
def biased_selection(pop, fitness, num_parents):
    # weigh the score for each parent
    weighted_fit=[fit/np.sum(fitness) for fit in fitness]
    #choose indices of parents according to probability given from the relative weights
    parents=np.random.choice(np.arange(len(fitness)),size=num_parents,p=weighted_fit)
    return pop[parents,:]

#2
def recombination(parents, offspring_size):
    offspring = np.zeros(offspring_size).astype(int)
    
    def choose_parents(parents):
    #choose at random parents
        parent1=parents[np.random.randint(0,parents.shape[0])]
        # avoid mating with oneself
        available_mates=parents[(parents!=parent1).sum(axis=1)>0]
        if available_mates.shape[0]<1:
          parent2=parent1
        else:
          parent2=available_mates[np.random.randint(0,available_mates.shape[0])]
        return parent1,parent2
       
    for i in range(offspring_size[0]):
        parent1,parent2=choose_parents(parents)
        # randox choose features from parent 1
        random_features=np.random.randint(0,2,size=offspring_size[1])
        inheritance1=parent1*random_features
        #choose completing features from parent 2
        inheritance2=parent2*(1-(random_features==1).astype(int))
        #combine
        offspring[i]=inheritance1+inheritance2
    return offspring

#3
def mutation(offspring_recombination,mutation_chance=0.1):
    for idx in range(offspring_recombination.shape[0]):
        #for each instance,create a series of features to be mutated
        mutate_feature=np.random.choice([0,1],size=offspring_recombination.shape[1],p=[1-mutation_chance,mutation_chance])
        #mutate by different value for every selected feature
        random_value = np.random.randint(-100, 100, offspring_recombination.shape[1])
        offspring_recombination[idx, :] += mutate_feature * random_value
    return offspring_recombination

# %%
# GA Parameters
formula_degree = 4
number_of_solutions = 1000
number_of_parents = 250
population_size = (number_of_solutions,formula_degree) 
number_of_generations = 20
#added for challenge no.4
tol=0.1
best_outputs = []

# Genesis
new_population = np.random.randint(low=0, high=10000, size=(1000,formula_degree))
print("The population of the first generation: ")
print(new_population)

# Evolution
print ("\nEvolution:")
for generation in range(number_of_generations):

    fitness = fitness_function(data, new_population)
    print("Generation = ", generation, "\tBest fitness = ", round(1/np.max(fitness),5))
    best_outputs.append(round(1/np.max(fitness),5))
    #4 - early stopping criteria:
    if (generation>1):
      if (np.abs(best_outputs[generation-2]-best_outputs[generation])<tol)&(np.abs(best_outputs[generation-3]-best_outputs[generation])<tol):
        print(" stopped after {} genarations due to lack of improvement for 3 generations straight".format(generation))
        break

    parents = biased_selection(new_population, fitness, number_of_parents)
    offspring_recombination = recombination(parents, offspring_size=(population_size[0]-parents.shape[0], formula_degree))
    offspring_mutation = mutation(offspring_recombination)
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation

# Results
print("\nThe population of the last generation: ")
print(new_population)
fitness = fitness_function(data, new_population)
best_match_idx = np.where(fitness == np.max(fitness))
print("Best solution: ", new_population[best_match_idx, :])

# Chart
plt.plot(best_outputs)
plt.xlabel("Generation")
plt.ylabel("Best Fitness Score")
plt.show()
# Out:
# The population of the first generation:
# [[5403   78 1231 1895]
#  [4274 2010 8676 8411]
#  [2095 6303 8740 1765]
#  ...
#  [4918  221 3548 7973]
#  [9303  673 3602 1415]
#  [1971 3014 5820  384]]
#
# Evolution:
# Generation =  0 	Best fitness =  18027739764.72482
# Generation =  1 	Best fitness =  2041823745.1363
# Generation =  2 	Best fitness =  10229883.14205
# Generation =  3 	Best fitness =  7846.62008
# Generation =  4 	Best fitness =  88.71474
# Generation =  5 	Best fitness =  0.00659
# Generation =  6 	Best fitness =  0.00659
# Generation =  7 	Best fitness =  0.00659
# Generation =  8 	Best fitness =  0.00659
#  stopped after 8 genarations due to lack of improvement for 3 generations straight
#
# The population of the last generation:
# [[ -35   90 2939 5306]
#  [ -35   90 2939 5306]
#  [ -35   90 2939 5306]
#  ...
#  [ -38  264 1287 5297]
#  [ -35   90 2939 5306]
#  [ -35  264 1287 5306]]
# Best solution:  [[[ -35   90 2939 5306]
#   [ -35   90 2939 5306]
#   [ -35   90 2939 5306]
#   ...
#   [ -35   90 2939 5306]
#   [ -35   90 2939 5306]
#   [ -35   90 2939 5306]]]

# %% [markdown]
# ## Part 2: Solving Different Problems With the Same GA

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f2e6893e-2bd1-458c-a9dd-f1dbc955a3ed" name="files[]" multiple disabled />
#      <output id="result-f2e6893e-2bd1-458c-a9dd-f1dbc955a3ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EMR-Blood.xlsx to EMR-Blood.xlsx

# %% [markdown]
# Below is a reminder of the K-Means algorithm you implemented in Assignment 21X.

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D


xlsx = pd.ExcelFile(io.BytesIO(uploaded['EMR-Blood.xlsx']))
sheet1 = xlsx.parse(0)
sheet1.set_index("Key", inplace=True)

variables1 = ["K","WBC","Hgb"]
EMR3d1 = sheet1.loc[:, variables1].values

y_pred_KMeans1 = KMeans(n_clusters=3).fit_predict(EMR3d1)

def make_chart (chart_data, y_pred, labels):
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.set_xlabel(labels[0])
    ax.set_ylabel(labels[1])
    ax.set_zlabel(labels[2])
    ax.scatter(chart_data[:,0], chart_data[:,1], chart_data[:,2], c=y_pred)

make_chart(EMR3d1, y_pred_KMeans1, variables1)

# %% [markdown]
# ### Challenge 232
# Solve the same clustering problem with a GA **without assuming K** (no iteration over differnet Ks), by trying to minimize the intra-cluster distances and maximize the inter-cluster distances.
#
# **hint: You can build the population as the cluster assignment of each point or as cluster centers (consider coordinates boundaries)

# %%
from sklearn.metrics.pairwise import euclidean_distances
from scipy.spatial.distance import squareform

from sklearn.metrics import  silhouette_score

# in this solution we'll initialize different cluster centroids and evolve the fittest ones according to a chi-score (that balnces within and between  group distances)

def generate_ranom_centroids(data,rows):
    return np.concatenate(([np.random.uniform(low=np.min(data[:,i]),high=np.max(data[:,i]),size=(rows,1)) for i in range(data.shape[1])]),axis=1)
    
def chscore(data,centroids):
    WCSS=np.sum(np.min(euclidean_distances(data,centroids),axis=0))
    BCSS=np.sum(euclidean_distances(centroids,centroids),axis=1)
    return BCSS*(data.shape[0]-data.shape[1])*(WCSS*(data.shape[1]-1))


def recombination(parents, offspring_size):
    offspring = np.zeros(offspring_size)
    
    def choose_parents(parents):
    #choose at random parents
        parent1=parents[np.random.randint(0,parents.shape[0])]
        # avoid mating with oneself
        available_mates=parents[(parents!=parent1).sum(axis=1)>0]
        if available_mates.shape[0]<1:
          print("lack of mating diversity")
          parent2=parent1
        else:
          parent2=available_mates[np.random.randint(0,available_mates.shape[0])]
        return parent1,parent2
       
    for i in range(offspring_size[0]):
        parent1,parent2=choose_parents(parents)
        # randox choose features from parent 1
        random_features=np.random.randint(0,2,size=offspring_size[1])
        inheritance1=parent1*random_features
        #choose completing features from parent 2
        inheritance2=parent2*(1-(random_features==1).astype(int))
        #combine
        offspring[i]=(inheritance1+inheritance2)
    return offspring


def mutation(offspring_recombination,mutation_chance=0.1):
    for idx in range(offspring_recombination.shape[0]):
        mutate_feature=np.random.choice([0,1],size=offspring_recombination.shape[1],p=[1-mutation_chance,mutation_chance])
                        
        random_value = np.random.uniform(np.min(offspring_recombination), np.max(offspring_recombination), offspring_recombination.shape[1])
        offspring_recombination[idx, :] += mutate_feature * random_value
    return offspring_recombination

# %%
features=EMR3d1.shape[1]
initial_centroids=100
num_parents=int(initial_centroids*.5)
pop_size = (initial_centroids,features) 
number_of_generations = 1000
tol=0.1
best_outputs = []

#create dictionaries to save 2 properties: best silhouette scores and best predictions for each generation
sil={}
predictions={}


#genesis
centroid=generate_ranom_centroids(EMR3d1,initial_centroids)    

for generation in range(number_of_generations):
    #create a prediction vector according to current generation's available centroids
    labels=np.argmin(euclidean_distances(EMR3d1,centroid),axis=1)
    #Eventually we'll get a prediction vector that converges into a single label, when that happens we don't have any room for further evolvment
    if len(np.unique(labels))<2:
        print("broke at {}th generation due to lack of diversity in predictions".format(generation))
        break
    predictions[generation]=labels
    sil[generation]=silhouette_score(EMR3d1, labels)
    #create a chi-score to bias selectcentroids for next generations
    chi=chscore(EMR3d1,centroid)

    print("Generation = ", generation, "\tSilhouette score = ", silhouette_score(EMR3d1, labels),"number of k's: ", len(np.unique(labels)))
    
    parents = biased_selection(centroid, chi, num_parents)
    offspring_recombination = recombination(parents, offspring_size=(centroid.shape[0]-num_parents, centroid.shape[1]))        
    offspring_mutation = mutation(offspring_recombination)
    centroid[0:num_parents, :] = parents
    centroid[num_parents:, :] = offspring_mutation

#choose best generation outcomes
best_sil=np.max(list(sil.values()))  
best_gen=list(sil.values()).index(best_sil)
best_labels=predictions[best_gen]
best_labels=pd.Series(best_labels).replace({np.unique(best_labels)[i]:i for i in range(len(np.unique(best_labels)))})
optimal_ks=len(np.unique(best_labels))
make_chart(EMR3d1, best_labels, variables1)
print("Best Generation = ", best_gen, "\tSilhouette score = ", best_sil,"number of k's: ", optimal_ks)
# Out:
# Generation =  0 	Silhouette score =  0.1446956460276587 number of k's:  32
# Generation =  1 	Silhouette score =  0.10258238744102867 number of k's:  25
# Generation =  2 	Silhouette score =  0.12082152157239263 number of k's:  19
# Generation =  3 	Silhouette score =  0.1186799395019686 number of k's:  14
# Generation =  4 	Silhouette score =  0.18515990836062046 number of k's:  11
# Generation =  5 	Silhouette score =  0.22943305245077528 number of k's:  9
# Generation =  6 	Silhouette score =  0.2946991390210454 number of k's:  8
# Generation =  7 	Silhouette score =  0.3022401515909368 number of k's:  8
# Generation =  8 	Silhouette score =  0.4275421278350474 number of k's:  4
# Generation =  9 	Silhouette score =  0.16434529754030344 number of k's:  3
# broke at 10th generation due to lack of diversity in predictions
# Best Generation =  8 	Silhouette score =  0.4275421278350474 number of k's:  4

# %% [markdown]
# unfortounatley the evolvement happens to fast, we can see a steep jump between different k's.
# after a bit of wxpirementation, we added some restrictions to the chi score vector we fed into the parent selector in order to moderate the rate of centroid evolvement

# %%
features=EMR3d1.shape[1]
initial_centroids=100
num_parents=int(initial_centroids*.5)
pop_size = (initial_centroids,features) 
number_of_generations = 1000
tol=0.1
best_outputs = []

#create dictionaries to save 2 properties: best silhouette scores and best predictions for each generation
sil={}
predictions={}


#genesis
centroid=generate_ranom_centroids(EMR3d1,initial_centroids)    

for generation in range(number_of_generations):
    #create a prediction vector according to current generation's available centroids
    labels=np.argmin(euclidean_distances(EMR3d1,centroid),axis=1)
    #Eventually we'll get a prediction vector that converges into a single label, when that happens we don't have any room for further evolvment
    if len(np.unique(labels))<2:
        print("broke at {}th generation due to lack of diversity in predictions".format(generation))
        break
    predictions[generation]=labels
    sil[generation]=silhouette_score(EMR3d1, labels)
    #create a chi-score to bias selectcentroids for next generations
    chi=chscore(EMR3d1,centroid)
    # moderate the rate of change to favor bigger clusters 
    chi[np.unique(labels, return_counts=True)[0]]*=np.unique(labels, return_counts=True)[1]
 

    print("Generation = ", generation, "\tSilhouette score = ", silhouette_score(EMR3d1, labels),"number of k's: ", len(np.unique(labels)))
    
    parents = biased_selection(centroid, chi, num_parents)
    offspring_recombination = recombination(parents, offspring_size=(centroid.shape[0]-num_parents, centroid.shape[1]))        
    offspring_mutation = mutation(offspring_recombination)
    centroid[0:num_parents, :] = parents
    centroid[num_parents:, :] = offspring_mutation

#choose best generation outcomes
best_sil=np.max(list(sil.values()))  
best_gen=list(sil.values()).index(best_sil)
best_labels=predictions[best_gen]
best_labels=pd.Series(best_labels).replace({np.unique(best_labels)[i]:i for i in range(len(np.unique(best_labels)))})
optimal_ks=len(np.unique(best_labels))
make_chart(EMR3d1, best_labels, variables1)
print("Best Generation = ", best_gen, "\tSilhouette score = ", best_sil,"number of k's: ", optimal_ks)
# Out:
# Generation =  0 	Silhouette score =  0.1628642051364242 number of k's:  35
# Generation =  1 	Silhouette score =  -0.01959209206424843 number of k's:  33
# Generation =  2 	Silhouette score =  0.13413140777581492 number of k's:  24
# Generation =  3 	Silhouette score =  0.14197786813063726 number of k's:  24
# Generation =  4 	Silhouette score =  0.13959955866420173 number of k's:  27
# Generation =  5 	Silhouette score =  0.18375162019327843 number of k's:  20
# Generation =  6 	Silhouette score =  0.23933693868308317 number of k's:  21
# Generation =  7 	Silhouette score =  0.261071862198753 number of k's:  16
# Generation =  8 	Silhouette score =  0.242283268555382 number of k's:  15
# Generation =  9 	Silhouette score =  0.19052549156941329 number of k's:  17
# Generation =  10 	Silhouette score =  0.10346094024216612 number of k's:  16
# Generation =  11 	Silhouette score =  0.20375613331638978 number of k's:  17
# Generation =  12 	Silhouette score =  0.2380674699955846 number of k's:  14
# Generation =  13 	Silhouette score =  0.3227098460027229 number of k's:  14
# Generation =  14 	Silhouette score =  0.26677082041728317 number of k's:  14
# Generation =  15 	Silhouette score =  0.25230877561482895 number of k's:  13
# Generation =  16 	Silhouette score =  0.2412879415322993 number of k's:  15
# Generation =  17 	Silhouette score =  0.3218359937852881 number of k's:  11
# Generation =  18 	Silhouette score =  0.2861694593994785 number of k's:  11
# Generation =  19 	Silhouette score =  0.34829787509805654 number of k's:  10
# Generation =  20 	Silhouette score =  0.2997887793354024 number of k's:  9
# Generation =  21 	Silhouette score =  0.405440065425067 number of k's:  9
# Generation =  22 	Silhouette score =  0.41749601737706493 number of k's:  9
# Generation =  23 	Silhouette score =  0.3558514612698456 number of k's:  10
# Generation =  24 	Silhouette score =  0.38748645576583113 number of k's:  9
# Generation =  25 	Silhouette score =  0.38748645576583113 number of k's:  9
# Generation =  26 	Silhouette score =  0.342790285913418 number of k's:  11
# Generation =  27 	Silhouette score =  0.4060398720965711 number of k's:  7
# Generation =  28 	Silhouette score =  0.45147397063978156 number of k's:  7
# Generation =  29 	Silhouette score =  0.3385371285056918 number of k's:  10
# Generation =  30 	Silhouette score =  0.3385371285056918 number of k's:  10
# Generation =  31 	Silhouette score =  0.30150258942671954 number of k's:  11
# Generation =  32 	Silhouette score =  0.3264538973266298 number of k's:  11
# Generation =  33 	Silhouette score =  0.2824668016054205 number of k's:  11
# Generation =  34 	Silhouette score =  0.2824668016054205 number of k's:  11
# Generation =  35 	Silhouette score =  0.28784580616360916 number of k's:  11
# Generation =  36 	Silhouette score =  0.3113381612058882 number of k's:  10
# Generation =  37 	Silhouette score =  0.30325489002011163 number of k's:  10
# Generation =  38 	Silhouette score =  0.313869288185607 number of k's:  10
# Generation =  39 	Silhouette score =  0.3631180211588091 number of k's:  9
# Generation =  40 	Silhouette score =  0.3873517079242611 number of k's:  8
# Generation =  41 	Silhouette score =  0.3873517079242611 number of k's:  8
# Generation =  42 	Silhouette score =  0.3873517079242611 number of k's:  8
# Generation =  43 	Silhouette score =  0.3873517079242611 number of k's:  8
# Generation =  44 	Silhouette score =  0.3873517079242611 number of k's:  8
# Generation =  45 	Silhouette score =  0.38909130140522896 number of k's:  9
# Generation =  46 	Silhouette score =  0.3729003809072555 number of k's:  7
# Generation =  47 	Silhouette score =  0.3970269305565367 number of k's:  8
# Generation =  48 	Silhouette score =  0.3970269305565367 number of k's:  8
# Generation =  49 	Silhouette score =  0.3970269305565367 number of k's:  8
# Generation =  50 	Silhouette score =  0.3970269305565367 number of k's:  8
# Generation =  51 	Silhouette score =  0.38389848394133474 number of k's:  8
# Generation =  52 	Silhouette score =  0.38389848394133474 number of k's:  8
# Generation =  53 	Silhouette score =  0.38389848394133474 number of k's:  8
# Generation =  54 	Silhouette score =  0.38389848394133474 number of k's:  8
# Generation =  55 	Silhouette score =  0.3615208420099936 number of k's:  7
# Generation =  56 	Silhouette score =  0.3615208420099936 number of k's:  7
# Generation =  57 	Silhouette score =  0.43688773293544103 number of k's:  6
# Generation =  58 	Silhouette score =  0.4503243680507157 number of k's:  7
# Generation =  59 	Silhouette score =  0.4503243680507157 number of k's:  7
# Generation =  60 	Silhouette score =  0.4503243680507157 number of k's:  7
# Generation =  61 	Silhouette score =  0.4416718634134598 number of k's:  6
# Generation =  62 	Silhouette score =  0.4535343052841915 number of k's:  7
# Generation =  63 	Silhouette score =  0.4503243680507157 number of k's:  7
# Generation =  64 	Silhouette score =  0.38343583877137744 number of k's:  7
# Generation =  65 	Silhouette score =  0.46345281466591765 number of k's:  7
# Generation =  66 	Silhouette score =  0.46345281466591765 number of k's:  7
# Generation =  67 	Silhouette score =  0.46345281466591765 number of k's:  7
# Generation =  68 	Silhouette score =  0.43688773293544103 number of k's:  6
# Generation =  69 	Silhouette score =  0.40998599461684393 number of k's:  7
# Generation =  70 	Silhouette score =  0.43688773293544103 number of k's:  6
# Generation =  71 	Silhouette score =  0.43688773293544103 number of k's:  6
# Generation =  72 	Silhouette score =  0.43688773293544103 number of k's:  6
# Generation =  73 	Silhouette score =  0.43688773293544103 number of k's:  6
# Generation =  74 	Silhouette score =  0.43688773293544103 number of k's:  6
# Generation =  75 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  76 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  77 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  78 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  79 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  80 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  81 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  82 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  83 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  84 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  85 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  86 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  87 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  88 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  89 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  90 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  91 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  92 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  93 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  94 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  95 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  96 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  97 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  98 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  99 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  100 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  101 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  102 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  103 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  104 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  105 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  106 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  107 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  108 	Silhouette score =  0.46439627850084547 number of k's:  5
# Generation =  109 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  110 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  111 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  112 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  113 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  114 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  115 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  116 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  117 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  118 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  119 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  120 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  121 	Silhouette score =  0.5286711432651989 number of k's:  4
# Generation =  122 	Silhouette score =  0.3843793026063052 number of k's:  5
# Generation =  123 	Silhouette score =  0.3843793026063052 number of k's:  5
# Generation =  124 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  125 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  126 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  127 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  128 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  129 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  130 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  131 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  132 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  133 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  134 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  135 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  136 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  137 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  138 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  139 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  140 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  141 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  142 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  143 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  144 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  145 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  146 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  147 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  148 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  149 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  150 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  151 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  152 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  153 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  154 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  155 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  156 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  157 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  158 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  159 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  160 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  161 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  162 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  163 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  164 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  165 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  166 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  167 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  168 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  169 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  170 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  171 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  172 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  173 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  174 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  175 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  176 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  177 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  178 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  179 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  180 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  181 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  182 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  183 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  184 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  185 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  186 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  187 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  188 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  189 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  190 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  191 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  192 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  193 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  194 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  195 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  196 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  197 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  198 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  199 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  200 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  201 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  202 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  203 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  204 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  205 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  206 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  207 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  208 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  209 	Silhouette score =  0.35418957985595234 number of k's:  5
# Generation =  210 	Silhouette score =  0.35418957985595234 number of k's:  5
# Generation =  211 	Silhouette score =  0.5386320842710236 number of k's:  4
# Generation =  212 	Silhouette score =  0.35418957985595234 number of k's:  5
# Generation =  213 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  214 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  215 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  216 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  217 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  218 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  219 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  220 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  221 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  222 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  223 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  224 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  225 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  226 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  227 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  228 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  229 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  230 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  231 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  232 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  233 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  234 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  235 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  236 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  237 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  238 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  239 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  240 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  241 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  242 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  243 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  244 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  245 	Silhouette score =  0.3843793026063052 number of k's:  5
# Generation =  246 	Silhouette score =  0.3843793026063052 number of k's:  5
# Generation =  247 	Silhouette score =  0.3843793026063052 number of k's:  5
# Generation =  248 	Silhouette score =  0.3843793026063052 number of k's:  5
# Generation =  249 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  250 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  251 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  252 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  253 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  254 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  255 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  256 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  257 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  258 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  259 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  260 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  261 	Silhouette score =  0.46439627850084547 number of k's:  5
# Generation =  262 	Silhouette score =  0.46439627850084547 number of k's:  5
# Generation =  263 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  264 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  265 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  266 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  267 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  268 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  269 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  270 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  271 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  272 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  273 	Silhouette score =  0.5286711432651989 number of k's:  4
# Generation =  274 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  275 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  276 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  277 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  278 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  279 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  280 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  281 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  282 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  283 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  284 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  285 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  286 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  287 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  288 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  289 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  290 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  291 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  292 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  293 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  294 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  295 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  296 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  297 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  298 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  299 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  300 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  301 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  302 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  303 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  304 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  305 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  306 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  307 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  308 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  309 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  310 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  311 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  312 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  313 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  314 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  315 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  316 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  317 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  318 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  319 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  320 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  321 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  322 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  323 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  324 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  325 	Silhouette score =  0.5286711432651989 number of k's:  4
# Generation =  326 	Silhouette score =  0.5286711432651989 number of k's:  4
# Generation =  327 	Silhouette score =  0.4379277990790476 number of k's:  5
# Generation =  328 	Silhouette score =  0.4379277990790476 number of k's:  5
# Generation =  329 	Silhouette score =  0.4379277990790476 number of k's:  5
# Generation =  330 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  331 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  332 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  333 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  334 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  335 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  336 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  337 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  338 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  339 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  340 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  341 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  342 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  343 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  344 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  345 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  346 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  347 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  348 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  349 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  350 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  351 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  352 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  353 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  354 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  355 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  356 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  357 	Silhouette score =  0.5286711432651989 number of k's:  4
# Generation =  358 	Silhouette score =  0.5286711432651989 number of k's:  4
# Generation =  359 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  360 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  361 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  362 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  363 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  364 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  365 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  366 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  367 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  368 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  369 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  370 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  371 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  372 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  373 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  374 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  375 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  376 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  377 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  378 	Silhouette score =  0.45080091353852403 number of k's:  5
# Generation =  379 	Silhouette score =  0.45080091353852403 number of k's:  5
# Generation =  380 	Silhouette score =  0.45080091353852403 number of k's:  5
# Generation =  381 	Silhouette score =  0.45080091353852403 number of k's:  5
# Generation =  382 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  383 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  384 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  385 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  386 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  387 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  388 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  389 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  390 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  391 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  392 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  393 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  394 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  395 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  396 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  397 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  398 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  399 	Silhouette score =  0.3843793026063052 number of k's:  5
# Generation =  400 	Silhouette score =  0.46439627850084547 number of k's:  5
# Generation =  401 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  402 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  403 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  404 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  405 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  406 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  407 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  408 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  409 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  410 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  411 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  412 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  413 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  414 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  415 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  416 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  417 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  418 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  419 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  420 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  421 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  422 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  423 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  424 	Silhouette score =  0.4512678318856436 number of k's:  5
# Generation =  425 	Silhouette score =  0.5386320842710236 number of k's:  4
# Generation =  426 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  427 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  428 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  429 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  430 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  431 	Silhouette score =  0.22593884734386338 number of k's:  5
# Generation =  432 	Silhouette score =  0.22593884734386338 number of k's:  5
# Generation =  433 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  434 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  435 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  436 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  437 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  438 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  439 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  440 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  441 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  442 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  443 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  444 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  445 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  446 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  447 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  448 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  449 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  450 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  451 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  452 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  453 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  454 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  455 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  456 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  457 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  458 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  459 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  460 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  461 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  462 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  463 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  464 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  465 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  466 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  467 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  468 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  469 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  470 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  471 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  472 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  473 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  474 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  475 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  476 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  477 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  478 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  479 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  480 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  481 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  482 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  483 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  484 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  485 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  486 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  487 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  488 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  489 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  490 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  491 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  492 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  493 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  494 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  495 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  496 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  497 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  498 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  499 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  500 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  501 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  502 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  503 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  504 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  505 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  506 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  507 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  508 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  509 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  510 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  511 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  512 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  513 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  514 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  515 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  516 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  517 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  518 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  519 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  520 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  521 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  522 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  523 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  524 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  525 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  526 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  527 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  528 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  529 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  530 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  531 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  532 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  533 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  534 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  535 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  536 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  537 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  538 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  539 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  540 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  541 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  542 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  543 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  544 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  545 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  546 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  547 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  548 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  549 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  550 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  551 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  552 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  553 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  554 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  555 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  556 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  557 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  558 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  559 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  560 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  561 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  562 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  563 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  564 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  565 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  566 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  567 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  568 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  569 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  570 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  571 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  572 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  573 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  574 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  575 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  576 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  577 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  578 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  579 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  580 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  581 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  582 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  583 	Silhouette score =  0.22593884734386338 number of k's:  5
# Generation =  584 	Silhouette score =  0.22593884734386338 number of k's:  5
# Generation =  585 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  586 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  587 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  588 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  589 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  590 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  591 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  592 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  593 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  594 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  595 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  596 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  597 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  598 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  599 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  600 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  601 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  602 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  603 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  604 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  605 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  606 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  607 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  608 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  609 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  610 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  611 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  612 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  613 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  614 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  615 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  616 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  617 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  618 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  619 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  620 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  621 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  622 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  623 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  624 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  625 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  626 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  627 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  628 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  629 	Silhouette score =  0.28730105057661415 number of k's:  5
# ...
# Generation =  793 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  794 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  795 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  796 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  797 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  798 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  799 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  800 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  801 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  802 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  803 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  804 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  805 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  806 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  807 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  808 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  809 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  810 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  811 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  812 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  813 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  814 	Silhouette score =  0.22593884734386338 number of k's:  5
# Generation =  815 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  816 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  817 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  818 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  819 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  820 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  821 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  822 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  823 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  824 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  825 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  826 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  827 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  828 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  829 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  830 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  831 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  832 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  833 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  834 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  835 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  836 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  837 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  838 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  839 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  840 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  841 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  842 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  843 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  844 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  845 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  846 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  847 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  848 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  849 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  850 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  851 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  852 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  853 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  854 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  855 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  856 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  857 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  858 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  859 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  860 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  861 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  862 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  863 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  864 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  865 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  866 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  867 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  868 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  869 	Silhouette score =  0.22593884734386338 number of k's:  5
# Generation =  870 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  871 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  872 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  873 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  874 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  875 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  876 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  877 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  878 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  879 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  880 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  881 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  882 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  883 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  884 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  885 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  886 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  887 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  888 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  889 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  890 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  891 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  892 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  893 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  894 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  895 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  896 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  897 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  898 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  899 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  900 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  901 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  902 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  903 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  904 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  905 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  906 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  907 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  908 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  909 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  910 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  911 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  912 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  913 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  914 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  915 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  916 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  917 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  918 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  919 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  920 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  921 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  922 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  923 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  924 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  925 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  926 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  927 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  928 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  929 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  930 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  931 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  932 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  933 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  934 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  935 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  936 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  937 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  938 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  939 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  940 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  941 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  942 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  943 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  944 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  945 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  946 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  947 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  948 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  949 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  950 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  951 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  952 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  953 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  954 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  955 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  956 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  957 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  958 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  959 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  960 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  961 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  962 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  963 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  964 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  965 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  966 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  967 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  968 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  969 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  970 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  971 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  972 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  973 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  974 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  975 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  976 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  977 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  978 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  979 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  980 	Silhouette score =  0.618700482413808 number of k's:  3
# Generation =  981 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  982 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  983 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  984 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  985 	Silhouette score =  0.4330313977632199 number of k's:  4
# Generation =  986 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  987 	Silhouette score =  0.4723463413866821 number of k's:  4
# Generation =  988 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  989 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  990 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  991 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  992 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  993 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  994 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  995 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  996 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  997 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  998 	Silhouette score =  0.28730105057661415 number of k's:  5
# Generation =  999 	Silhouette score =  0.4330313977632199 number of k's:  4
# Best Generation =  500 	Silhouette score =  0.618700482413808 number of k's:  3

# %% [markdown]
# We can see that in terms of finding an optimal solution this methodworks fine, but we geta lot of back and forth in terms of silhouette scores.
#
# we belive that a further optimization to the weighting method is requiered but this solution is good enough to solve this specific classification problem

# %% [markdown]
# ## Challenge 233: Reconstruct Image (Bonus)
# In this part you will attemp to generate an image which is closest to a target image given.
#
# First we will load the image from a file:

# %%
import matplotlib.image as mpimg

img=mpimg.imread('pexels-photo-57905.jpeg')

# %% [markdown]
# For simplicity (and running time), we focus on a small part of the image:

# %%
import matplotlib.pyplot as plt
imgplot = plt.imshow(img[100:200,200:300,0])

# %% [markdown]
# And we will define this part as out target image to reconstruct:

# %%
target = img[100:200,200:300,0]

# %% [markdown]
# Your mission is to generate an image starting at random noise. The goal is to get an image as close as possible to the target. Don;t worry if it's still noisy...
# FYI: GA are not the best solution for these types of problems ;)
# You can use these blog posts to give you ideas:
# https://towardsdatascience.com/genetic-algorithm-implementation-in-python-5ab67bb124a6
#
# https://heartbeat.fritz.ai/reproducing-images-using-a-genetic-algorithm-with-python-91fc701ff84

# %%
# Your code here
